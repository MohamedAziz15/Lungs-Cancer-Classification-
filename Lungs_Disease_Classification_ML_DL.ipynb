# %% [markdown]
# ## Lungs Cancer Disease Dataset
#
# ### Brief about our dataset
#
#
# #### This dataset contains information on patients with lung cancer, including their age, gender, air pollution exposure, alcohol use, dust allergy, occupational hazards, genetic risk, chronic lung disease, balanced diet, obesity, smoking status, passive smoker status, chest pain, coughing of blood, fatigue levels , weight loss , shortness of breath , wheezing , swallowing difficulty , clubbing of finger nails , frequent colds , dry coughs , and snoring. By analyzing this data we can gain insight into what causes lung cancer and how best to treat it
#
# #### Columns
#
# - Age: The age of the patient. (Numeric)
# - Gender: The gender of the patient. (Categorical)
# - Air Pollution: The level of air pollution exposure of the patient. (Categorical)
# - Alcohol use: The level of alcohol use of the patient. (Categorical)
# - Dust Allergy: The level of dust allergy of the patient. (Categorical)
# - OccuPational Hazards: The level of occupational hazards of the patient. (Categorical)
# - Genetic Risk: The level of genetic risk of the patient. (Categorical)
# - chronic Lung Disease: The level of chronic lung disease of the patient. (Categorical)
# - Balanced Diet: The level of balanced diet of the patient. (Categorical)
# - Obesity: The level of obesity of the patient. (Categorical)
# - Smoking: The level of smoking of the patient. (Categorical)
# - Passive Smoker: The level of passive smoker of the patient. (Categorical)
# - Chest Pain: The level of chest pain of the patient. (Categorical)
# - Coughing of Blood: The level of coughing of blood of the patient. (Categorical)
# - Fatigue: The level of fatigue of the patient. (Categorical)
# - Weight Loss: The level of weight loss of the patient. (Categorical)
# - Shortness of Breath: The level of shortness of breath of the patient. (Categorical)
# - Wheezing: The level of wheezing of the patient. (Categorical)
# - Swallowing Difficulty: The level of swallowing difficulty of the patient. (Categorical)
# - Clubbing of Finger Nails: The level of clubbing of finger nails of the patient. (Categorical)
#
# #### Target
#
# - Level : Intensity of the cancer(Low, Medium or High)

# %% [markdown]
# ## Libraries Used

# %%
import seaborn as sns
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.metrics import classification_report, accuracy_score, recall_score, precision_score, f1_score,confusion_matrix, mean_absolute_error , r2_score , mean_squared_error, mean_absolute_percentage_error
from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier
import keras
from keras.models import Sequential
from keras.layers import Dense, Dropout, Activation
# from tensorflow.keras.callbacks import EarlyStopping
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ## Data Review

# %%
df = pd.read_csv("cancer patient data sets.csv", sep=",",encoding="UTF-8")
df.head()
# Out:
#    index Patient Id  Age  Gender  Air Pollution  Alcohol use  Dust Allergy  \
# 0      0         P1   33       1              2            4             5
# 1      1        P10   17       1              3            1             5
# 2      2       P100   35       1              4            5             6
# 3      3      P1000   37       1              7            7             7
# 4      4       P101   46       1              6            8             7
#
#    OccuPational Hazards  Genetic Risk  chronic Lung Disease  ...  Fatigue  \
# 0                     4             3                     2  ...        3
# 1                     3             4                     2  ...        1
# 2                     5             5                     4  ...        8
# 3                     7             6                     7  ...        4
# 4                     7             7                     6  ...        3
#
#    Weight Loss  Shortness of Breath  Wheezing  Swallowing Difficulty  \
# 0            4                    2         2                      3
# 1            3                    7         8                      6
# 2            7                    9         2                      1
# 3            2                    3         1                      4
# 4            2                    4         1                      4
#
#    Clubbing of Finger Nails  Frequent Cold  Dry Cough  Snoring   Level
# 0                         1              2          3        4     Low
# 1                         2              1          7        2  Medium
# 2                         4              6          7        2    High
# 3                         5              6          7        5    High
# 4                         2              4          2        3    High
#
# [5 rows x 26 columns]

# %%
# getting the dataset's rows and columns by invoking the shape() function
df.shape
# Out:
# (1000, 26)

# %%
# getting information about columns using info() function
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 26 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   index                     1000 non-null   int64
#  1   Patient Id                1000 non-null   object
#  2   Age                       1000 non-null   int64
#  3   Gender                    1000 non-null   int64
#  4   Air Pollution             1000 non-null   int64
#  5   Alcohol use               1000 non-null   int64
#  6   Dust Allergy              1000 non-null   int64
#  7   OccuPational Hazards      1000 non-null   int64
#  8   Genetic Risk              1000 non-null   int64
#  9   chronic Lung Disease      1000 non-null   int64
#  10  Balanced Diet             1000 non-null   int64
#  11  Obesity                   1000 non-null   int64
#  12  Smoking                   1000 non-null   int64
#  13  Passive Smoker            1000 non-null   int64
#  14  Chest Pain                1000 non-null   int64
#  15  Coughing of Blood         1000 non-null   int64
#  16  Fatigue                   1000 non-null   int64
#  17  Weight Loss               1000 non-null   int64
#  18  Shortness of Breath       1000 non-null   int64
#  19  Wheezing                  1000 non-null   int64
#  20  Swallowing Difficulty     1000 non-null   int64
#  21  Clubbing of Finger Nails  1000 non-null   int64
#  22  Frequent Cold             1000 non-null   int64
#  23  Dry Cough                 1000 non-null   int64
#  24  Snoring                   1000 non-null   int64
#  25  Level                     1000 non-null   object
# dtypes: int64(24), object(2)
# memory usage: 203.2+ KB

# %%
#Check types for all the columns using dtypes
df.dtypes
# Out:
# index                        int64
# Patient Id                  object
# Age                          int64
# Gender                       int64
# Air Pollution                int64
# Alcohol use                  int64
# Dust Allergy                 int64
# OccuPational Hazards         int64
# Genetic Risk                 int64
# chronic Lung Disease         int64
# Balanced Diet                int64
# Obesity                      int64
# Smoking                      int64
# Passive Smoker               int64
# Chest Pain                   int64
# Coughing of Blood            int64
# Fatigue                      int64
# Weight Loss                  int64
# Shortness of Breath          int64
# Wheezing                     int64
# Swallowing Difficulty        int64
# Clubbing of Finger Nails     int64
# Frequent Cold                int64
# Dry Cough                    int64
# Snoring                      int64
# Level                       object
# dtype: object

# %%
# getting statistical information for every column in dataset by iterating over the columns by a for loop and getting these data using describe() function
for column in df.columns:
    print(df[column].describe())
    print("\n----------------------------\n")
# Out:
# count    1000.000000
# mean      499.500000
# std       288.819436
# min         0.000000
# 25%       249.750000
# 50%       499.500000
# 75%       749.250000
# max       999.000000
# Name: index, dtype: float64
#
# ----------------------------
#
# count     1000
# unique    1000
# top       P652
# freq         1
# Name: Patient Id, dtype: object
#
# ----------------------------
#
# count    1000.000000
# mean       37.174000
# std        12.005493
# min        14.000000
# 25%        27.750000
# 50%        36.000000
# 75%        45.000000
# max        73.000000
# Name: Age, dtype: float64
#
# ----------------------------
#
# count    1000.000000
# mean        1.402000
# std         0.490547
# min         1.000000
# 25%         1.000000
# 50%         1.000000
# 75%         2.000000
# max         2.000000
# Name: Gender, dtype: float64
#
# ----------------------------
#
# count    1000.0000
# mean        3.8400
# std         2.0304
# min         1.0000
# 25%         2.0000
# 50%         3.0000
# 75%         6.0000
# max         8.0000
# Name: Air Pollution, dtype: float64
#
# ----------------------------
#
# count    1000.000000
# mean        4.563000
# std         2.620477
# min         1.000000
# 25%         2.000000
# 50%         5.000000
# 75%         7.000000
# max         8.000000
# Name: Alcohol use, dtype: float64
#
# ----------------------------
#
# count    1000.000000
# mean        5.165000
# std         1.980833
# min         1.000000
# 25%         4.000000
# 50%         6.000000
# 75%         7.000000
# max         8.000000
# Name: Dust Allergy, dtype: float64
#
# ----------------------------
#
# count    1000.000000
# mean        4.840000
# std         2.107805
# min         1.000000
# 25%         3.000000
# 50%         5.000000
# 75%         7.000000
# max         8.000000
# Name: OccuPational Hazards, dtype: float64
#
# ----------------------------
#
# count    1000.000000
# mean        4.580000
# std         2.126999
# min         1.000000
# 25%         2.000000
# 50%         5.000000
# 75%         7.000000
# max         7.000000
# Name: Genetic Risk, dtype: float64
#
# ----------------------------
#
# count    1000.000000
# mean        4.380000
# std         1.848518
# min         1.000000
# 25%         3.000000
# 50%         4.000000
# 75%         6.000000
# max         7.000000
# Name: chronic Lung Disease, dtype: float64
#
# ----------------------------
#
# count    1000.000000
# mean        4.491000
# std         2.135528
# min         1.000000
# 25%         2.000000
# 50%         4.000000
# 75%         7.000000
# max         7.000000
# Name: Balanced Diet, dtype: float64
#
# ----------------------------
#
# count    1000.000000
# mean        4.465000
# std         2.124921
# min         1.000000
# 25%         3.000000
# 50%         4.000000
# 75%         7.000000
# max         7.000000
# Name: Obesity, dtype: float64
#
# ----------------------------
#
# count    1000.000000
# mean        3.948000
# std         2.495902
# min         1.000000
# 25%         2.000000
# 50%         3.000000
# 75%         7.000000
# max         8.000000
# Name: Smoking, dtype: float64
#
# ----------------------------
#
# count    1000.000000
# mean        4.195000
# std         2.311778
# min         1.000000
# 25%         2.000000
# 50%         4.000000
# 75%         7.000000
# max         8.000000
# Name: Passive Smoker, dtype: float64
#
# ----------------------------
#
# count    1000.000000
# mean        4.438000
# std         2.280209
# min         1.000000
# 25%         2.000000
# 50%         4.000000
# 75%         7.000000
# max         9.000000
# Name: Chest Pain, dtype: float64
#
# ----------------------------
#
# count    1000.000000
# mean        4.859000
# std         2.427965
# min         1.000000
# 25%         3.000000
# 50%         4.000000
# 75%         7.000000
# max         9.000000
# Name: Coughing of Blood, dtype: float64
#
# ----------------------------
#
# count    1000.000000
# mean        3.856000
# std         2.244616
# min         1.000000
# 25%         2.000000
# 50%         3.000000
# 75%         5.000000
# max         9.000000
# Name: Fatigue, dtype: float64
#
# ----------------------------
#
# count    1000.000000
# mean        3.855000
# std         2.206546
# min         1.000000
# 25%         2.000000
# 50%         3.000000
# 75%         6.000000
# max         8.000000
# Name: Weight Loss, dtype: float64
#
# ----------------------------
#
# count    1000.000000
# mean        4.240000
# std         2.285087
# min         1.000000
# 25%         2.000000
# 50%         4.000000
# 75%         6.000000
# max         9.000000
# Name: Shortness of Breath, dtype: float64
#
# ----------------------------
#
# count    1000.000000
# mean        3.777000
# std         2.041921
# min         1.000000
# 25%         2.000000
# 50%         4.000000
# 75%         5.000000
# max         8.000000
# Name: Wheezing, dtype: float64
#
# ----------------------------
#
# count    1000.000000
# mean        3.746000
# std         2.270383
# min         1.000000
# 25%         2.000000
# 50%         4.000000
# 75%         5.000000
# max         8.000000
# Name: Swallowing Difficulty, dtype: float64
#
# ----------------------------
#
# count    1000.000000
# mean        3.923000
# std         2.388048
# min         1.000000
# 25%         2.000000
# 50%         4.000000
# 75%         5.000000
# max         9.000000
# Name: Clubbing of Finger Nails, dtype: float64
#
# ----------------------------
#
# count    1000.000000
# mean        3.536000
# std         1.832502
# min         1.000000
# 25%         2.000000
# 50%         3.000000
# 75%         5.000000
# max         7.000000
# Name: Frequent Cold, dtype: float64
#
# ----------------------------
#
# count    1000.000000
# mean        3.853000
# std         2.039007
# min         1.000000
# 25%         2.000000
# 50%         4.000000
# 75%         6.000000
# max         7.000000
# Name: Dry Cough, dtype: float64
#
# ----------------------------
#
# count    1000.000000
# mean        2.926000
# std         1.474686
# min         1.000000
# 25%         2.000000
# 50%         3.000000
# 75%         4.000000
# max         7.000000
# Name: Snoring, dtype: float64
#
# ----------------------------
#
# count     1000
# unique       3
# top       High
# freq       365
# Name: Level, dtype: object
#
# ----------------------------

# %%
# trying to know if there is any cell in the sheet that doesn't contain any value by using isnull() and any() functions if there is the output will be true false otherwise
df.isnull().any()
# Out:
# index                       False
# Patient Id                  False
# Age                         False
# Gender                      False
# Air Pollution               False
# Alcohol use                 False
# Dust Allergy                False
# OccuPational Hazards        False
# Genetic Risk                False
# chronic Lung Disease        False
# Balanced Diet               False
# Obesity                     False
# Smoking                     False
# Passive Smoker              False
# Chest Pain                  False
# Coughing of Blood           False
# Fatigue                     False
# Weight Loss                 False
# Shortness of Breath         False
# Wheezing                    False
# Swallowing Difficulty       False
# Clubbing of Finger Nails    False
# Frequent Cold               False
# Dry Cough                   False
# Snoring                     False
# Level                       False
# dtype: bool

# %% [markdown]
# ##### there is no missing data found in the sheet

# %%
#checking duplicates
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ##### No duplicates are found

# %%
for column in df.columns:
    print(df[column].value_counts())
# Out:
# 0      1
# 671    1
# 658    1
# 659    1
# 660    1
#       ..
# 338    1
# 339    1
# 340    1
# 341    1
# 999    1
# Name: index, Length: 1000, dtype: int64
# P652    1
# P432    1
# P774    1
# P468    1
# P312    1
#        ..
# P47     1
# P67     1
# P528    1
# P567    1
# P616    1
# Name: Patient Id, Length: 1000, dtype: int64
# 35    77
# 33    69
# 38    69
# 37    51
# 44    51
# 27    48
# 45    42
# 48    40
# 26    37
# 28    32
# 32    31
# 52    31
# 62    30
# 25    30
# 24    30
# 46    23
# 36    21
# 39    21
# 17    20
# 42    20
# 19    20
# 47    20
# 53    19
# 29    19
# 23    19
# 22    19
# 18    18
# 55    11
# 65    10
# 61    10
# 64    10
# 73    10
# 49    10
# 34    10
# 31     9
# 14     9
# 54     1
# 51     1
# 43     1
# 63     1
# Name: Age, dtype: int64
# 1    598
# 2    402
# Name: Gender, dtype: int64
# 6    326
# 2    201
# 3    173
# 1    141
# 4     90
# 7     30
# 5     20
# 8     19
# Name: Air Pollution, dtype: int64
# 2    202
# 8    188
# 7    167
# 1    152
# 5     90
# 3     80
# 6     80
# 4     41
# Name: Alcohol use, dtype: int64
# 7    405
# 4    133
# 5    111
# 6    110
# 3    101
# 2     70
# 1     60
# 8     10
# Name: Dust Allergy, dtype: int64
# 7    365
# 3    151
# 2    132
# 5    130
# 4    112
# 1     50
# 6     30
# 8     30
# Name: OccuPational Hazards, dtype: int64
# 7    327
# 2    212
# 3    173
# 6    108
# 5    100
# 1     40
# 4     40
# Name: Genetic Risk, dtype: int64
# 6    308
# 2    173
# 3    141
# 4    141
# 7    107
# 5     80
# 1     50
# Name: chronic Lung Disease, dtype: int64
# 7    296
# 2    231
# 3    173
# 6    159
# 4     61
# 1     40
# 5     40
# Name: Balanced Diet, dtype: int64
# 7    356
# 3    193
# 4    191
# 2    140
# 1     70
# 6     30
# 5     20
# Name: Obesity, dtype: int64
# 2    222
# 7    207
# 1    181
# 3    172
# 8     89
# 6     60
# 4     59
# 5     10
# Name: Smoking, dtype: int64
# 2    284
# 7    187
# 4    161
# 3    140
# 8    108
# 1     60
# 5     30
# 6     30
# Name: Passive Smoker, dtype: int64
# 7    296
# 4    191
# 2    181
# 3    153
# 1     80
# 6     40
# 8     30
# 9     19
# 5     10
# Name: Chest Pain, dtype: int64
# 7    187
# 4    172
# 3    171
# 2    121
# 8    119
# 1     71
# 9     60
# 5     50
# 6     49
# Name: Coughing of Blood, dtype: int64
# 3    212
# 2    211
# 4    180
# 1    110
# 8    109
# 5     89
# 6     50
# 9     39
# Name: Fatigue, dtype: int64
# 2    280
# 7    230
# 3    150
# 1    121
# 5    100
# 4     60
# 6     49
# 8     10
# Name: Weight Loss, dtype: int64
# 2    243
# 6    201
# 3    140
# 4     90
# 7     89
# 5     87
# 1     80
# 9     70
# Name: Shortness of Breath, dtype: int64
# 2    240
# 5    171
# 4    163
# 1    149
# 7    139
# 6     68
# 3     60
# 8     10
# Name: Wheezing, dtype: int64
# 1    221
# 4    189
# 2    160
# 5    110
# 8    110
# 6     91
# 3     90
# 7     29
# Name: Swallowing Difficulty, dtype: int64
# 2    240
# 4    220
# 1    131
# 5    120
# 3    100
# 9     80
# 8     59
# 7     40
# 6     10
# Name: Clubbing of Finger Nails, dtype: int64
# 3    230
# 2    192
# 4    180
# 6    170
# 1    139
# 7     69
# 5     20
# Name: Frequent Cold, dtype: int64
# 2    251
# 7    168
# 4    141
# 5    131
# 1    119
# 3    101
# 6     89
# Name: Dry Cough, dtype: int64
# 2    300
# 3    211
# 1    170
# 5    139
# 4    131
# 6     39
# 7     10
# Name: Snoring, dtype: int64
# High      365
# Medium    332
# Low       303
# Name: Level, dtype: int64

# %% [markdown]
# ## EDA & Data Preprocessing

# %%
# giving labels to our values
labels = {
    0: "extremely low",
    1: "very low",
    2: "low",
    3: "below medium average",
    4: "medium",
    5: "above medium average",
    6: "high",
    7: "very high",
    8: "extremely high",
    9: "Maximum"
}

# %%
plt.title("Age Range in Data")
plt.bar(df['Age'], height=df.shape[0],width=.5)
# Out:
# <BarContainer object of 1000 artists>

# %%
plt.figure(figsize = (7,4))
sns.kdeplot(df.Age, shade = True, color = "b")
plt.title("Age Count", fontsize = 18)
plt.show()

# %%
df1 = df.drop(["Level","Patient Id","index"],axis=1)

# %% [markdown]
# #### Correlated features

# %%
plt.subplots(figsize = (24, 24))
sns.heatmap(df1.corr(), annot = True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Overview
#
# - It also shows us that obesity, air pollution, balanced diet, cough of blood, passive smoker is strong correlated with lung caner, therefore we should be alert when these factors occur to us.

# %%
correlationC=[]
for column in df1.columns :
    for columnC in df1.columns:
        a = df1[column].corr(df1[columnC])
        if a > 0.8 and (column != columnC) :
            if a in correlationC:
                continue
            else :
                correlationC.append(a)         
                print (column +" column has high correlation with column "+ columnC)
                print(df1[column].corr(df1[columnC]))
                print("*******************************")
# Out:
# Alcohol use column has high correlation with column Dust Allergy
# 0.8186435195099219
# *******************************
# Alcohol use column has high correlation with column OccuPational Hazards
# 0.8787859206801716
# *******************************
# Alcohol use column has high correlation with column Genetic Risk
# 0.8772098877053738
# *******************************
# Dust Allergy column has high correlation with column OccuPational Hazards
# 0.835859771456722
# *******************************
# OccuPational Hazards column has high correlation with column Genetic Risk
# 0.8930485226784646
# *******************************
# OccuPational Hazards column has high correlation with column chronic Lung Disease
# 0.8582838533909183
# *******************************
# Genetic Risk column has high correlation with column Alcohol use
# 0.8772098877053737
# *******************************
# Genetic Risk column has high correlation with column OccuPational Hazards
# 0.8930485226784647
# *******************************
# Genetic Risk column has high correlation with column chronic Lung Disease
# 0.836230827381165
# *******************************
# Genetic Risk column has high correlation with column Chest Pain
# 0.8317508263736832
# *******************************
# Obesity column has high correlation with column Coughing of Blood
# 0.8148047650547859
# *******************************

# %%
correlationC.sort()
correlationC.reverse()
correlationC
# Out:
# [0.8930485226784647,
#  0.8930485226784646,
#  0.8787859206801716,
#  0.8772098877053738,
#  0.8772098877053737,
#  0.8582838533909183,
#  0.836230827381165,
#  0.835859771456722,
#  0.8317508263736832,
#  0.8186435195099219,
#  0.8148047650547859]

# %% [markdown]
# ### Decoding

# %% [markdown]
# #### the discrete column (Level) from the dataset needs to be repaired :

# %%
df["Gender"] = df["Gender"].replace([1,2],["Female","Male"])
df["Air Pollution"] = df["Air Pollution"].replace([1,2,3,4,5,6,7,8],[labels[1],labels[2],labels[3],labels[4],labels[5],labels[6],labels[7],labels[8]])
df["Dust Allergy"] = df["Dust Allergy"].replace([1,2,3,4,5,6,7,8],[labels[1],labels[2],labels[3],labels[4],labels[5],labels[6],labels[7],labels[8]])
df["OccuPational Hazards"] = df["OccuPational Hazards"].replace([1,2,3,4,5,6,7,8],[labels[1],labels[2],labels[3],labels[4],labels[5],labels[6],labels[7],labels[8]])
df["Genetic Risk"] = df["Genetic Risk"].replace([1,2,3,4,5,6,7],[labels[1],labels[2],labels[3],labels[4],labels[5],labels[6],labels[7]])
df["chronic Lung Disease"] = df["chronic Lung Disease"].replace([1,2,3,4,5,6,7],[labels[1],labels[2],labels[3],labels[4],labels[5],labels[6],labels[7]])
df["Fatigue"] = df["Fatigue"].replace([1,2,3,4,5,6,7,8,9],[labels[1],labels[2],labels[3],labels[4],labels[5],labels[6],labels[7],labels[8],labels[9]])
df["Weight Loss"] = df["Weight Loss"].replace([1,2,3,4,5,6,7,8],[labels[1],labels[2],labels[3],labels[4],labels[5],labels[6],labels[7],labels[8]])
df["Shortness of Breath"] = df["Shortness of Breath"].replace([1,2,3,4,5,6,7,8,9],[labels[1],labels[2],labels[3],labels[4],labels[5],labels[6],labels[7],labels[8],labels[9]])
df["Wheezing"] = df["Wheezing"].replace([1,2,3,4,5,6,7,8],[labels[1],labels[2],labels[3],labels[4],labels[5],labels[6],labels[7],labels[8]])
df["Swallowing Difficulty"] = df["Swallowing Difficulty"].replace([1,2,3,4,5,6,7,8],[labels[1],labels[2],labels[3],labels[4],labels[5],labels[6],labels[7],labels[8]])
df["Clubbing of Finger Nails"] = df["Clubbing of Finger Nails"].replace([1,2,3,4,5,6,7,8,9],[labels[1],labels[2],labels[3],labels[4],labels[5],labels[6],labels[7],labels[8],labels[9]])
df["Frequent Cold"] = df["Frequent Cold"].replace([1,2,3,4,5,6,7],[labels[1],labels[2],labels[3],labels[4],labels[5],labels[6],labels[7]])
df["Dry Cough"] = df["Dry Cough"].replace([1,2,3,4,5,6,7],[labels[1],labels[2],labels[3],labels[4],labels[5],labels[6],labels[7]])
df["Snoring"] = df["Snoring"].replace([1,2,3,4,5,6,7],[labels[1],labels[2],labels[3],labels[4],labels[5],labels[6],labels[7]])
df["Obesity"] = df["Obesity"].replace([1,2,3,4,5,6,7],[labels[1],labels[2],labels[3],labels[4],labels[5],labels[6],labels[7]])
df["Passive Smoker"] = df["Passive Smoker"].replace([1,2,3,4,5,6,7,8],[labels[1],labels[2],labels[3],labels[4],labels[5],labels[6],labels[7],labels[8]])

# %%
df["Passive Smoker"].value_counts()
# Out:
# low                     284
# very high               187
# medium                  161
# below medium average    140
# extremely high          108
# very low                 60
# above medium average     30
# high                     30
# Name: Passive Smoker, dtype: int64

# %%
df.Level.value_counts()
# Out:
# High      365
# Medium    332
# Low       303
# Name: Level, dtype: int64

# %%
plt.figure(figsize=(6,7))
plt.title("Level Column Values")
round(df["Level"].value_counts()/df.shape[0]*100,2).plot.pie(autopct= '%2.1f%%')
# Out:
# <AxesSubplot:title={'center':'Level Column Values'}, ylabel='Level'>

# %% [markdown]
# ##### target column is balanced

# %% [markdown]
# #### How is OccuPational Hazards is affected by Genetic Risk ?

# %%
f = plt.figure(figsize=(18, 6))
plt.xlabel("OccuPational Hazards")
plt.ylabel("Genetic Risk")
plt.title("Relation between OccuPational Hazards and Genetic Risk")
plt.scatter(df["OccuPational Hazards"],df["Genetic Risk"],alpha=0.7,c="red",linewidths=7)

# %% [markdown]
# ##### There's a postive correlation between them as people with high genetic risk are having high occupational hazards

# %% [markdown]
# #### Who are more susceptible to disease ?

# %%
plt.subplots(figsize=(20, 7))

sns.histplot(data=df, x=df["OccuPational Hazards"], hue=df["Gender"], multiple="dodge", shrink=.8,palette=["pink","darkblue"]).set(title='Relation Between OccuPational Hazards and Gender')
# Out:
# [Text(0.5, 1.0, 'Relation Between OccuPational Hazards and Gender')]

# %%
df.Gender.value_counts()
# Out:
# Female    598
# Male      402
# Name: Gender, dtype: int64

# %% [markdown]
# ##### females are more likly to get lungs disease with high ratios compared to men

# %%
plt.subplots(figsize=(20, 7))
plt.title("Number of Passive Smokers")
sns.histplot(data=df, x=df["Passive Smoker"],color= "darkcyan")
# Out:
# <AxesSubplot:title={'center':'Number of Passive Smokers'}, xlabel='Passive Smoker', ylabel='Count'>

# %% [markdown]
# ##### Most Passive Smokers are Smoking in low values nearly 300 Smoker

# %% [markdown]
# #### Who is drinking the most alcohols ?

# %%
df3= df.copy()

df3['AgeRange'] = None
df3.loc[(df3['Age'] > 14) & (df3["Age"] < 18), 'AgeRange'] = "Teenager"
df3.loc[(df3['Age'] > 18) & (df3["Age"] < 45), 'AgeRange'] = "Adult"
df3.loc[(df3['Age'] > 45) & (df3["Age"] < 74), 'AgeRange'] = "senile"


sns.catplot(data=df3, x="AgeRange", y="Alcohol use",aspect=20/10,height=5).set(title='Relation Between Age and Alcohol use')

# %% [markdown]
# ##### Adults are the most people to drink alcohols ( 18 < Adults < 45 )

# %% [markdown]
# #### What is the Relation Genetic Risk and chronic Lung Disease ?

# %%
plt.subplots(figsize=(20, 7))

plt.hist(df['Genetic Risk'], bins=25, alpha=0.45, color='red')
plt.hist(df['chronic Lung Disease'], bins=50, alpha=0.45, color='blue')

plt.title("Relation Genetic Risk and chronic Lung Disease ")

  
plt.legend(['Genetic Risk', 
            'chronic Lung Disease'])

# %% [markdown]
# ##### Seems like Genetic Risk has no effect on chronic Lung Disease

# %%
df6 = pd.read_csv("cancer patient data sets.csv", sep=",",encoding="UTF-8")

plt.subplots(figsize=(20, 7))

plt.hist(df6['Genetic Risk'], bins=25, alpha=0.45, color='red')
plt.hist(df6['chronic Lung Disease'], bins=50, alpha=0.45, color='blue')

plt.title("Relation Genetic Risk and chronic Lung Disease ")
  
plt.legend(['Genetic Risk', 
            'chronic Lung Disease'])

# %%
f = plt.figure(figsize=(18, 6))
plt.xlabel("OccuPational Hazards")
plt.ylabel("Genetic Risk")
plt.title("Relation between OccuPational Hazards and Genetic Risk")
plt.scatter(df6["OccuPational Hazards"],df6["Genetic Risk"],alpha=0.7,c="red",linewidths=7)

# %% [markdown]
# #### How is Obesity affecting Coughing of blood level ?

# %%
plt.figure(figsize=(18, 6))
plt.title("Relation between Obesity and Coughing of Blood")
sns.barplot(data=df, x="Obesity", y="Coughing of Blood",palette="husl")
# Out:
# <AxesSubplot:title={'center':'Relation between Obesity and Coughing of Blood'}, xlabel='Obesity', ylabel='Coughing of Blood'>

# %% [markdown]
# ##### as expected people with high obesity tends to have more coughing of blood

# %%
plt.figure(figsize=(18, 6))
plt.title("Relation between Obesity and Coughing of Blood")
sns.barplot(data=df6, x="Obesity", y="Coughing of Blood",palette="husl")
# Out:
# <AxesSubplot:title={'center':'Relation between Obesity and Coughing of Blood'}, xlabel='Obesity', ylabel='Coughing of Blood'>

# %% [markdown]
# #### is there's any outliers in the dataset ?

# %%
# drawing a box plots for all columns

df6.plot(kind='box', subplots=True, layout=(5,5), figsize=(18,15))
plt.show()

# %%
plt.title("Age Column Box Plot")
sns.boxenplot(df.Age)
# Out:
# <AxesSubplot:title={'center':'Age Column Box Plot'}, xlabel='Age'>

# %% [markdown]
# ##### No outliers found in it

# %%
# using df6 for later classification
df6.dtypes
# Out:
# index                        int64
# Patient Id                  object
# Age                          int64
# Gender                       int64
# Air Pollution                int64
# Alcohol use                  int64
# Dust Allergy                 int64
# OccuPational Hazards         int64
# Genetic Risk                 int64
# chronic Lung Disease         int64
# Balanced Diet                int64
# Obesity                      int64
# Smoking                      int64
# Passive Smoker               int64
# Chest Pain                   int64
# Coughing of Blood            int64
# Fatigue                      int64
# Weight Loss                  int64
# Shortness of Breath          int64
# Wheezing                     int64
# Swallowing Difficulty        int64
# Clubbing of Finger Nails     int64
# Frequent Cold                int64
# Dry Cough                    int64
# Snoring                      int64
# Level                       object
# dtype: object

# %% [markdown]
# ### Encoding

# %%
# making an object named le from LabelEncoder Class
le = LabelEncoder()

# transforming the datatype
df6['Level'] = le.fit_transform(df6['Level'])
df6['Patient Id'] = le.fit_transform(df6['Patient Id'])

# %%
df6.dtypes
# Out:
# index                       int64
# Patient Id                  int32
# Age                         int64
# Gender                      int64
# Air Pollution               int64
# Alcohol use                 int64
# Dust Allergy                int64
# OccuPational Hazards        int64
# Genetic Risk                int64
# chronic Lung Disease        int64
# Balanced Diet               int64
# Obesity                     int64
# Smoking                     int64
# Passive Smoker              int64
# Chest Pain                  int64
# Coughing of Blood           int64
# Fatigue                     int64
# Weight Loss                 int64
# Shortness of Breath         int64
# Wheezing                    int64
# Swallowing Difficulty       int64
# Clubbing of Finger Nails    int64
# Frequent Cold               int64
# Dry Cough                   int64
# Snoring                     int64
# Level                       int32
# dtype: object

# %% [markdown]
# ### Train Test Split

# %%
# Split data between predictors and output variable
x = df6.drop(["Level","Patient Id","index"],axis=1).values
y = df.Level.values

# %%
x_train, x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=42)

# %%
x_train
# Out:
# array([[28,  2,  1, ...,  7,  7,  5],
#        [53,  1,  6, ...,  1,  7,  6],
#        [28,  2,  1, ...,  7,  7,  5],
#        ...,
#        [36,  2,  2, ...,  3,  2,  3],
#        [49,  1,  6, ...,  6,  7,  2],
#        [49,  1,  6, ...,  6,  7,  2]], dtype=int64)

# %%
x_test
# Out:
# array([[48,  2,  1, ...,  1,  2,  1],
#        [62,  1,  6, ...,  3,  4,  2],
#        [22,  1,  6, ...,  3,  4,  2],
#        ...,
#        [28,  1,  6, ...,  4,  5,  3],
#        [44,  1,  2, ...,  3,  2,  3],
#        [46,  2,  1, ...,  7,  7,  5]], dtype=int64)

# %%
y_train
# Out:
# array(['Medium', 'High', 'Medium', 'Medium', 'Low', 'Low', 'Low', 'High',
#        'Low', 'Low', 'Medium', 'High', 'Low', 'Low', 'High', 'High',
#        'High', 'Medium', 'Medium', 'Low', 'Medium', 'High', 'High', 'Low',
#        'Medium', 'High', 'High', 'High', 'Medium', 'High', 'High', 'High',
#        'Low', 'High', 'Low', 'High', 'Medium', 'Medium', 'Medium', 'High',
#        'High', 'High', 'Medium', 'High', 'Medium', 'High', 'High',
#        'Medium', 'Medium', 'Medium', 'Medium', 'High', 'Medium', 'Low',
#        'Medium', 'Low', 'Medium', 'High', 'Low', 'High', 'Medium', 'High',
#        'High', 'Low', 'Low', 'High', 'High', 'Low', 'Medium', 'Low',
#        'Medium', 'Low', 'Medium', 'High', 'Medium', 'Medium', 'Medium',
#        'Low', 'Medium', 'Low', 'Medium', 'High', 'High', 'Low', 'High',
#        'Low', 'Medium', 'High', 'High', 'Low', 'Low', 'Medium', 'Medium',
#        'High', 'Medium', 'Low', 'Low', 'High', 'Low', 'Low', 'High',
#        'High', 'Low', 'High', 'Low', 'Low', 'Medium', 'High', 'High',
#        'Medium', 'Low', 'Medium', 'Medium', 'Low', 'High', 'Medium',
#        'Low', 'Medium', 'Low', 'Low', 'High', 'Low', 'Medium', 'Medium',
#        'High', 'Low', 'Medium', 'Low', 'Low', 'High', 'Low', 'High',
#        'Low', 'Medium', 'Low', 'High', 'Low', 'High', 'High', 'High',
#        'Low', 'Medium', 'Low', 'Low', 'Low', 'High', 'High', 'Medium',
#        'Medium', 'Low', 'Medium', 'Low', 'Low', 'Medium', 'Medium',
#        'High', 'Medium', 'High', 'High', 'Low', 'Low', 'Medium', 'Medium',
#        'Low', 'Low', 'High', 'High', 'Medium', 'Low', 'Medium', 'Low',
#        'Low', 'Medium', 'Low', 'Low', 'High', 'Low', 'Medium', 'High',
#        'Low', 'Medium', 'Low', 'Medium', 'Medium', 'High', 'High', 'Low',
#        'High', 'High', 'High', 'Medium', 'Low', 'High', 'High', 'Low',
#        'Low', 'Medium', 'High', 'High', 'High', 'High', 'High', 'High',
#        'High', 'Medium', 'High', 'Low', 'High', 'Low', 'Medium', 'Medium',
#        'Medium', 'High', 'Low', 'Low', 'Low', 'Medium', 'Low', 'Medium',
#        'High', 'High', 'Low', 'Low', 'Medium', 'High', 'Low', 'Medium',
#        'Low', 'Medium', 'Low', 'Medium', 'Medium', 'High', 'Medium',
#        'Low', 'Medium', 'Medium', 'Low', 'High', 'Low', 'Medium', 'High',
#        'Medium', 'High', 'Medium', 'Medium', 'Medium', 'Medium', 'High',
#        'Low', 'High', 'High', 'Low', 'Low', 'Medium', 'Medium', 'High',
#        'High', 'Low', 'Low', 'Medium', 'Medium', 'Low', 'Medium', 'Low',
#        'High', 'High', 'Medium', 'Medium', 'Low', 'Medium', 'High', 'Low',
#        'High', 'High', 'High', 'Low', 'Low', 'Low', 'Low', 'Low', 'High',
#        'High', 'Medium', 'High', 'Low', 'Low', 'High', 'Low', 'Low',
#        'High', 'Low', 'High', 'High', 'High', 'Medium', 'High', 'Medium',
#        'High', 'High', 'Low', 'Medium', 'Low', 'High', 'Medium', 'Medium',
#        'High', 'Low', 'High', 'Medium', 'Low', 'High', 'Low', 'Medium',
#        'High', 'High', 'High', 'Low', 'Medium', 'High', 'High', 'High',
#        'Medium', 'Low', 'High', 'High', 'Low', 'High', 'Medium', 'High',
#        'High', 'High', 'Medium', 'Low', 'Medium', 'Low', 'Low', 'Medium',
#        'Medium', 'Low', 'Medium', 'Low', 'Low', 'Low', 'Low', 'Low',
#        'Medium', 'Low', 'Low', 'Medium', 'High', 'Medium', 'Medium',
#        'High', 'Medium', 'High', 'Low', 'Low', 'High', 'Medium', 'Medium',
#        'High', 'High', 'Medium', 'Low', 'High', 'Medium', 'Medium',
#        'Medium', 'Medium', 'Low', 'High', 'Medium', 'Low', 'High', 'Low',
#        'High', 'Medium', 'Medium', 'Medium', 'High', 'Medium', 'Medium',
#        'High', 'High', 'Medium', 'High', 'Medium', 'Low', 'Medium',
#        'High', 'Low', 'Medium', 'High', 'Medium', 'Low', 'Medium', 'Low',
#        'Low', 'Medium', 'High', 'Medium', 'High', 'Low', 'High', 'Medium',
#        'Low', 'High', 'Low', 'Low', 'Medium', 'Low', 'High', 'Medium',
#        'High', 'Medium', 'Low', 'Medium', 'Medium', 'Low', 'High', 'High',
#        'Medium', 'Low', 'Medium', 'Medium', 'Low', 'Medium', 'Low',
#        'Medium', 'Medium', 'Low', 'Low', 'Low', 'High', 'High', 'Medium',
#        'Medium', 'High', 'Medium', 'High', 'Low', 'Low', 'Medium', 'Low',
#        'Medium', 'High', 'Medium', 'Low', 'Medium', 'Medium', 'Medium',
#        'High', 'Low', 'Medium', 'Low', 'Medium', 'Medium', 'Low', 'High',
#        'Low', 'High', 'High', 'High', 'High', 'High', 'High', 'High',
#        'High', 'Medium', 'Medium', 'High', 'High', 'Low', 'Medium', 'Low',
#        'Low', 'Medium', 'High', 'High', 'High', 'Medium', 'High',
#        'Medium', 'High', 'Low', 'Medium', 'High', 'High', 'Medium',
#        'Medium', 'Medium', 'Medium', 'Medium', 'High', 'Low', 'Low',
#        'Medium', 'Medium', 'Low', 'High', 'Medium', 'Medium', 'High',
#        'High', 'Low', 'Low', 'High', 'Low', 'Low', 'Medium', 'High',
#        'Medium', 'Medium', 'High', 'Medium', 'Medium', 'Medium', 'Low',
#        'Medium', 'Medium', 'Medium', 'Low', 'Low', 'Medium', 'Medium',
#        'High', 'Medium', 'High', 'High', 'Low', 'Medium', 'Low', 'High',
#        'High', 'Low', 'High', 'High', 'Medium', 'Medium', 'Low', 'High',
#        'Medium', 'Medium', 'High', 'Medium', 'Medium', 'Medium', 'Medium',
#        'High', 'Medium', 'High', 'High', 'Low', 'Medium', 'Medium', 'Low',
#        'Low', 'High', 'Low', 'Low', 'Medium', 'High', 'High', 'Low',
#        'High', 'Low', 'High', 'Medium', 'High', 'Medium', 'High', 'High',
#        'High', 'Medium', 'High', 'Low', 'Medium', 'Low', 'Medium',
#        'Medium', 'Medium', 'Low', 'Low', 'Low', 'Low', 'Medium', 'Low',
#        'High', 'Low', 'Low', 'Medium', 'High', 'Low', 'High', 'Medium',
#        'Medium', 'Medium', 'Medium', 'Medium', 'High', 'Medium', 'High',
#        'High', 'Medium', 'High', 'Medium', 'Low', 'Medium', 'Medium',
#        'High', 'Low', 'High', 'High', 'Medium', 'Medium', 'Low', 'Medium',
#        'High', 'Medium', 'High', 'Medium', 'Medium', 'Medium', 'Medium',
#        'High', 'High', 'High', 'Low', 'High', 'Medium', 'High', 'Medium',
#        'High', 'High', 'High', 'High', 'Low', 'Medium', 'Medium', 'High',
#        'Low', 'High', 'High', 'Medium', 'Low', 'High', 'Medium', 'Low',
#        'Low', 'Medium', 'High', 'Low', 'High', 'High', 'Medium', 'High',
#        'Medium', 'Low', 'High', 'Low', 'Medium', 'Medium', 'Medium',
#        'Low', 'Low', 'Low', 'Medium', 'Low', 'Medium', 'High', 'High',
#        'Low', 'Medium', 'Low', 'Medium', 'Medium', 'High', 'Low', 'Low',
#        'Low', 'Low', 'Low', 'Medium', 'High', 'High', 'Low', 'Low',
#        'High', 'High', 'Medium', 'Low', 'Low', 'Medium', 'Medium',
#        'Medium', 'Low', 'High', 'High', 'High', 'Low', 'Medium', 'Low',
#        'Low', 'Low', 'High', 'Medium', 'Low', 'Low', 'Medium', 'Low',
#        'High', 'High', 'High', 'Low', 'Medium', 'Low', 'High', 'Low',
#        'Medium', 'High', 'Low', 'High', 'Medium', 'High', 'High', 'Low',
#        'High', 'Low', 'Medium', 'Medium', 'Medium', 'High', 'Medium',
#        'High', 'High', 'Low', 'Low', 'Low', 'Low', 'Medium', 'High',
#        'High', 'Low', 'Low', 'High', 'Low', 'Low', 'High', 'High', 'High',
#        'Low', 'High', 'Medium', 'High', 'Low', 'High', 'Medium', 'Medium',
#        'Low', 'High', 'High', 'High', 'Medium', 'High', 'High', 'High',
#        'Medium', 'Low', 'Low', 'Medium', 'Medium', 'Low', 'High',
#        'Medium', 'Low', 'High', 'High', 'Medium', 'High', 'Medium',
#        'High', 'High', 'High', 'Low', 'High', 'Low', 'High', 'High',
#        'High', 'High', 'Low', 'High', 'Low', 'Medium', 'High', 'Low',
#        'Medium', 'High', 'High'], dtype=object)

# %%
y_test
# Out:
# array(['Medium', 'Medium', 'Medium', 'High', 'Medium', 'Medium', 'Medium',
#        'Medium', 'Medium', 'Medium', 'Low', 'Medium', 'Medium', 'Medium',
#        'Low', 'High', 'Low', 'High', 'High', 'High', 'High', 'Medium',
#        'Low', 'Medium', 'High', 'Low', 'Medium', 'High', 'Low', 'Low',
#        'Low', 'High', 'Medium', 'Low', 'Low', 'High', 'High', 'Medium',
#        'High', 'Low', 'High', 'High', 'Low', 'Medium', 'Medium', 'Low',
#        'Low', 'Medium', 'High', 'Low', 'Medium', 'High', 'Low', 'High',
#        'High', 'High', 'Low', 'High', 'High', 'Low', 'Medium', 'Low',
#        'High', 'High', 'Low', 'Medium', 'High', 'High', 'Medium', 'High',
#        'High', 'Low', 'Medium', 'Medium', 'Medium', 'Medium', 'High',
#        'Low', 'Low', 'Medium', 'Medium', 'Medium', 'Low', 'Medium',
#        'High', 'High', 'High', 'Low', 'High', 'High', 'Low', 'Low',
#        'Medium', 'High', 'High', 'High', 'High', 'High', 'Medium', 'Low',
#        'Low', 'High', 'Low', 'Low', 'Medium', 'High', 'High', 'Medium',
#        'Medium', 'Medium', 'Medium', 'High', 'High', 'Low', 'Medium',
#        'High', 'Medium', 'High', 'Medium', 'Medium', 'High', 'High',
#        'Low', 'Low', 'Medium', 'High', 'High', 'High', 'High', 'High',
#        'Low', 'Medium', 'Low', 'High', 'Medium', 'Low', 'Medium', 'High',
#        'Medium', 'Medium', 'Low', 'Medium', 'Low', 'Low', 'High',
#        'Medium', 'Low', 'High', 'Low', 'High', 'High', 'Low', 'Low',
#        'High', 'Low', 'High', 'High', 'High', 'Low', 'High', 'Low',
#        'High', 'High', 'High', 'High', 'Medium', 'Medium', 'High', 'High',
#        'High', 'High', 'Medium', 'High', 'High', 'Low', 'High', 'Medium',
#        'Low', 'Medium', 'High', 'Low', 'High', 'Low', 'Medium', 'High',
#        'Medium', 'High', 'Medium', 'Low', 'Medium', 'Low', 'Low',
#        'Medium', 'High', 'High', 'Medium', 'High', 'High', 'Low',
#        'Medium'], dtype=object)

# %% [markdown]
# #### Scalling the Data using Standard Scaler

# %%
# Scale train/ test predictors based on training data
s_scaler = StandardScaler().fit(x_train)
x_train_scaled = s_scaler.transform(x_train)
x_test_scaled = s_scaler.transform(x_test)

# %%
# Results summarizer function (scores, confusion matrix) for classification results
def resultsSummarizer(y_true, y_pred):
    cm = confusion_matrix(y_true, y_pred)
    acc = accuracy_score(y_true, y_pred)
    prec = precision_score(y_true, y_pred, average='macro')
    rec = recall_score(y_true, y_pred, average='macro')
    f1 = f1_score(y_true, y_pred, average='macro')
    
    
    plt.figure(figsize=(7, 6))
    
    sns.heatmap(cm,
                annot=True,
                cmap='Blues',
                xticklabels=labels.values(),
                yticklabels=labels.values()
               ) 
    
    plt.title('Confusion Matrix')
    plt.xlabel('Predicted Activity')
    plt.ylabel('Actual Activity')
    plt.show()
    
    print(f'Accuracy Score: ' + '{:.4%}'.format(acc))
    print(f'Precision Score: ' + '{:.4%}'.format(prec))
    print(f'Recall Score: ' + '{:.4%}'.format(rec))
    print(f'F_1 Score: ' + '{:.4%}'.format(f1))

# %% [markdown]
# #### Logistic Regression

# %%
lr = LogisticRegression()
lr.fit(x_train , y_train)
# Out:
# LogisticRegression()

# %%
lr.score(x_train , y_train)
# Out:
# 0.9975

# %%
lr.score(x_test , y_test)
# Out:
# 0.995

# %%
y_pred=lr.predict(x_test)
data=pd.DataFrame({'y_Test  ':y_test,'y_pred  ':y_pred})
data[:20]
# Out:
#    y_Test   y_pred
# 0    Medium   Medium
# 1    Medium   Medium
# 2    Medium   Medium
# 3      High     High
# 4    Medium   Medium
# 5    Medium   Medium
# 6    Medium   Medium
# 7    Medium   Medium
# 8    Medium   Medium
# 9    Medium   Medium
# 10      Low      Low
# 11   Medium   Medium
# 12   Medium   Medium
# 13   Medium   Medium
# 14      Low      Low
# 15     High     High
# 16      Low      Low
# 17     High     High
# 18     High     High
# 19     High     High

# %% [markdown]
# #### KNN

# %%
knn=KNeighborsClassifier(n_neighbors=5)

# %%
knn.fit(x_train,y_train)
# Out:
# KNeighborsClassifier()

# %%
knn.score(x_train,y_train)
# Out:
# 0.99875

# %%
knn.score(x_test,y_test)
# Out:
# 0.995

# %%
y_pred=knn.predict(x_test)
data=pd.DataFrame({'y_Test  ':y_test,'y_pred  ':y_pred})
data[:20]
# Out:
#    y_Test   y_pred
# 0    Medium   Medium
# 1    Medium   Medium
# 2    Medium   Medium
# 3      High     High
# 4    Medium   Medium
# 5    Medium   Medium
# 6    Medium   Medium
# 7    Medium   Medium
# 8    Medium   Medium
# 9    Medium   Medium
# 10      Low      Low
# 11   Medium   Medium
# 12   Medium   Medium
# 13   Medium   Medium
# 14      Low      Low
# 15     High     High
# 16      Low      Low
# 17     High     High
# 18     High     High
# 19     High     High

# %%
knn2 = KNeighborsClassifier(n_neighbors=5)
knn2.fit(x_train_scaled, y_train)
y_pred_knn = knn2.predict(x_test_scaled)

# %%
resultsSummarizer(y_test, y_pred_knn)
# Out:
# Accuracy Score: 100.0000%
# Precision Score: 100.0000%
# Recall Score: 100.0000%
# F_1 Score: 100.0000%

# %% [markdown]
# #### Random Forest Classifer

# %%
rfst = RandomForestClassifier(n_estimators=10,random_state=42)
rfst.fit(x_train_scaled, y_train)
y_pred_rfst = rfst.predict(x_test_scaled)

# %%
resultsSummarizer(y_pred_rfst, y_test)
# Out:
# Accuracy Score: 100.0000%
# Precision Score: 100.0000%
# Recall Score: 100.0000%
# F_1 Score: 100.0000%

# %% [markdown]
# #### Grid Search

# %%
C_grid = 0.02*np.arange(1,20)
gamma_grid = 0.02*np.arange(1,50)
print(C_grid,gamma_grid)
parameters = {'C': C_grid, 'gamma' : gamma_grid}
gridCV = GridSearchCV(SVC(kernel='rbf'), parameters, n_jobs=-1)             
gridCV.fit(x_train[:1000],y_train[:1000])
best_C = gridCV.best_params_['C']
best_gamma = gridCV.best_params_['gamma']

print("Best C "+str(best_C))
print("Best Gamma "+str(best_gamma))
# Out:
# [0.02 0.04 0.06 0.08 0.1  0.12 0.14 0.16 0.18 0.2  0.22 0.24 0.26 0.28
#  0.3  0.32 0.34 0.36 0.38] [0.02 0.04 0.06 0.08 0.1  0.12 0.14 0.16 0.18 0.2  0.22 0.24 0.26 0.28
#  0.3  0.32 0.34 0.36 0.38 0.4  0.42 0.44 0.46 0.48 0.5  0.52 0.54 0.56
#  0.58 0.6  0.62 0.64 0.66 0.68 0.7  0.72 0.74 0.76 0.78 0.8  0.82 0.84
#  0.86 0.88 0.9  0.92 0.94 0.96 0.98]
# Best C 0.12
# Best Gamma 0.02

# %% [markdown]
# ### Modelling using SVM kernel

# %% [markdown]
# #### Linear

# %%
lin = SVC(kernel='linear',C=best_C,gamma=best_gamma)
lin.fit(x_train, y_train)
# Out:
# SVC(C=0.12, gamma=0.02, kernel='linear')

# %%
y_pred_Linear = lin.predict(x_test)
print(classification_report(y_test, y_pred_Linear))
# Out:
#               precision    recall  f1-score   support
#
#         High       1.00      1.00      1.00        82
#          Low       1.00      1.00      1.00        55
#       Medium       1.00      1.00      1.00        63
#
#     accuracy                           1.00       200
#    macro avg       1.00      1.00      1.00       200
# weighted avg       1.00      1.00      1.00       200

# %%
resultsSummarizer(y_pred_Linear, y_test)
# Out:
# Accuracy Score: 100.0000%
# Precision Score: 100.0000%
# Recall Score: 100.0000%
# F_1 Score: 100.0000%

# %% [markdown]
# #### RBF

# %%
rbf = SVC(kernel='rbf',C=1,gamma=0.6)
rbf.fit(x_train, y_train)

y_pred_RBF = rbf.predict(x_test)
print(classification_report(y_test, y_pred_RBF))
# Out:
#               precision    recall  f1-score   support
#
#         High       1.00      0.99      0.99        82
#          Low       1.00      0.96      0.98        55
#       Medium       0.95      1.00      0.98        63
#
#     accuracy                           0.98       200
#    macro avg       0.98      0.98      0.98       200
# weighted avg       0.99      0.98      0.99       200

# %%
resultsSummarizer(y_test, y_pred_RBF)
# Out:
# Accuracy Score: 98.5000%
# Precision Score: 98.4848%
# Recall Score: 98.3814%
# F_1 Score: 98.4030%

# %% [markdown]
# ### Deep Learning Model

# %%
df10 = pd.read_csv("cancer patient data sets.csv", sep=",",encoding="UTF-8")

# %%
df10.Level = df10.Level.replace("Low", 0)
df10.Level = df10.Level.replace("Medium", 1)
df10.Level = df10.Level.replace("High", 2)
df10.Level = df10.Level.astype("int64")

# %%
x = df10.drop(["Level","Patient Id","index"], axis = 1)
y = pd.get_dummies(df["Level"])

# %%
model = Sequential()
model.add(Dense(8, activation = "relu", input_dim = x.shape[1]))
model.add(Dense(16, activation = "relu"))
model.add(Dropout(0.1))
model.add(Dense(8, activation = "relu"))
model.add(Dense(3, activation = "softmax"))

model.compile(optimizer = "adam", loss = "categorical_crossentropy", metrics = ["accuracy"])
#earlyStop = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=32)
dlModel = model.fit(x, y, epochs = 200, validation_split = 0.3)
# Out:
# Epoch 1/200
# 22/22 [==============================] - 0s 15ms/step - loss: 6.3810 - accuracy: 0.3400 - val_loss: 3.4579 - val_accuracy: 0.3433
# Epoch 2/200
# 22/22 [==============================] - 0s 1ms/step - loss: 3.3645 - accuracy: 0.3000 - val_loss: 2.0533 - val_accuracy: 0.2867
# Epoch 3/200
# 22/22 [==============================] - 0s 1ms/step - loss: 2.2014 - accuracy: 0.3214 - val_loss: 1.3813 - val_accuracy: 0.3800
# Epoch 4/200
# 22/22 [==============================] - 0s 1ms/step - loss: 1.4057 - accuracy: 0.4000 - val_loss: 1.0032 - val_accuracy: 0.4700
# Epoch 5/200
# 22/22 [==============================] - 0s 1ms/step - loss: 1.1864 - accuracy: 0.4271 - val_loss: 0.9037 - val_accuracy: 0.5367
# Epoch 6/200
# 22/22 [==============================] - 0s 1ms/step - loss: 1.0639 - accuracy: 0.4943 - val_loss: 0.8371 - val_accuracy: 0.6500
# Epoch 7/200
# 22/22 [==============================] - 0s 2ms/step - loss: 1.0167 - accuracy: 0.5214 - val_loss: 0.8020 - val_accuracy: 0.6733
# Epoch 8/200
# 22/22 [==============================] - 0s 1ms/step - loss: 0.9454 - accuracy: 0.5586 - val_loss: 0.7583 - val_accuracy: 0.6633
# Epoch 9/200
# 22/22 [==============================] - 0s 2ms/step - loss: 0.9251 - accuracy: 0.5643 - val_loss: 0.7249 - val_accuracy: 0.6900
# Epoch 10/200
# 22/22 [==============================] - 0s 2ms/step - loss: 0.8723 - accuracy: 0.5929 - val_loss: 0.7029 - val_accuracy: 0.7100
# Epoch 11/200
# 22/22 [==============================] - 0s 2ms/step - loss: 0.8444 - accuracy: 0.6000 - val_loss: 0.6774 - val_accuracy: 0.7533
# Epoch 12/200
# 22/22 [==============================] - 0s 1ms/step - loss: 0.8037 - accuracy: 0.6500 - val_loss: 0.6585 - val_accuracy: 0.7733
# Epoch 13/200
# 22/22 [==============================] - 0s 1ms/step - loss: 0.7765 - accuracy: 0.6243 - val_loss: 0.6438 - val_accuracy: 0.7633
# Epoch 14/200
# 22/22 [==============================] - 0s 2ms/step - loss: 0.7520 - accuracy: 0.6629 - val_loss: 0.6235 - val_accuracy: 0.7867
# Epoch 15/200
# 22/22 [==============================] - 0s 1ms/step - loss: 0.7593 - accuracy: 0.6686 - val_loss: 0.6027 - val_accuracy: 0.7967
# Epoch 16/200
# 22/22 [==============================] - 0s 1ms/step - loss: 0.7215 - accuracy: 0.6857 - val_loss: 0.5876 - val_accuracy: 0.7733
# Epoch 17/200
# 22/22 [==============================] - 0s 1ms/step - loss: 0.7292 - accuracy: 0.6557 - val_loss: 0.5737 - val_accuracy: 0.8067
# Epoch 18/200
# 22/22 [==============================] - 0s 1ms/step - loss: 0.6956 - accuracy: 0.6957 - val_loss: 0.5620 - val_accuracy: 0.8167
# Epoch 19/200
# 22/22 [==============================] - 0s 1ms/step - loss: 0.6737 - accuracy: 0.6871 - val_loss: 0.5484 - val_accuracy: 0.8067
# Epoch 20/200
# 22/22 [==============================] - 0s 1ms/step - loss: 0.6638 - accuracy: 0.7071 - val_loss: 0.5278 - val_accuracy: 0.8333
# Epoch 21/200
# 22/22 [==============================] - 0s 1ms/step - loss: 0.6474 - accuracy: 0.7214 - val_loss: 0.5137 - val_accuracy: 0.8167
# Epoch 22/200
# 22/22 [==============================] - 0s 1ms/step - loss: 0.6080 - accuracy: 0.7329 - val_loss: 0.5018 - val_accuracy: 0.8267
# Epoch 23/200
# 22/22 [==============================] - 0s 1ms/step - loss: 0.6287 - accuracy: 0.7100 - val_loss: 0.4888 - val_accuracy: 0.8233
# Epoch 24/200
# 22/22 [==============================] - 0s 1ms/step - loss: 0.5888 - accuracy: 0.7500 - val_loss: 0.4748 - val_accuracy: 0.8900
# Epoch 25/200
# 22/22 [==============================] - 0s 1ms/step - loss: 0.5724 - accuracy: 0.7700 - val_loss: 0.4638 - val_accuracy: 0.8500
# Epoch 26/200
# 22/22 [==============================] - 0s 2ms/step - loss: 0.5799 - accuracy: 0.7714 - val_loss: 0.4522 - val_accuracy: 0.8700
# Epoch 27/200
# 22/22 [==============================] - 0s 1ms/step - loss: 0.5524 - accuracy: 0.7871 - val_loss: 0.4352 - val_accuracy: 0.8767
# Epoch 28/200
# 22/22 [==============================] - 0s 1ms/step - loss: 0.5337 - accuracy: 0.7957 - val_loss: 0.4211 - val_accuracy: 0.8867
# Epoch 29/200
# 22/22 [==============================] - 0s 1ms/step - loss: 0.5059 - accuracy: 0.8186 - val_loss: 0.4064 - val_accuracy: 0.8967
# Epoch 30/200
# 22/22 [==============================] - 0s 1ms/step - loss: 0.4993 - accuracy: 0.8157 - val_loss: 0.3932 - val_accuracy: 0.8967
# Epoch 31/200
# 22/22 [==============================] - 0s 1ms/step - loss: 0.4901 - accuracy: 0.8214 - val_loss: 0.3811 - val_accuracy: 0.8933
# Epoch 32/200
# 22/22 [==============================] - 0s 1ms/step - loss: 0.4718 - accuracy: 0.8343 - val_loss: 0.3678 - val_accuracy: 0.9100
# Epoch 33/200
# 22/22 [==============================] - 0s 1ms/step - loss: 0.4758 - accuracy: 0.8371 - val_loss: 0.3570 - val_accuracy: 0.9033
# Epoch 34/200
# 22/22 [==============================] - 0s 1ms/step - loss: 0.4330 - accuracy: 0.8557 - val_loss: 0.3352 - val_accuracy: 0.9033
# Epoch 35/200
# 22/22 [==============================] - 0s 1ms/step - loss: 0.4392 - accuracy: 0.8443 - val_loss: 0.3245 - val_accuracy: 0.9033
# Epoch 36/200
# 22/22 [==============================] - 0s 1ms/step - loss: 0.4334 - accuracy: 0.8414 - val_loss: 0.3131 - val_accuracy: 0.9133
# Epoch 37/200
# 22/22 [==============================] - 0s 1ms/step - loss: 0.4110 - accuracy: 0.8443 - val_loss: 0.3019 - val_accuracy: 0.9033
# Epoch 38/200
# 22/22 [==============================] - 0s 1ms/step - loss: 0.3965 - accuracy: 0.8586 - val_loss: 0.2918 - val_accuracy: 0.9133
# Epoch 39/200
# 22/22 [==============================] - 0s 2ms/step - loss: 0.3857 - accuracy: 0.8643 - val_loss: 0.2815 - val_accuracy: 0.9133
# Epoch 40/200
# 22/22 [==============================] - 0s 2ms/step - loss: 0.3643 - accuracy: 0.8786 - val_loss: 0.2725 - val_accuracy: 0.9233
# Epoch 41/200
# 22/22 [==============================] - 0s 1ms/step - loss: 0.3639 - accuracy: 0.8657 - val_loss: 0.2642 - val_accuracy: 0.9233
# Epoch 42/200
# 22/22 [==============================] - 0s 1ms/step - loss: 0.3496 - accuracy: 0.8757 - val_loss: 0.2563 - val_accuracy: 0.9333
# Epoch 43/200
# 22/22 [==============================] - 0s 1ms/step - loss: 0.3303 - accuracy: 0.8843 - val_loss: 0.2450 - val_accuracy: 0.9233
# Epoch 44/200
# 22/22 [==============================] - 0s 2ms/step - loss: 0.3230 - accuracy: 0.8886 - val_loss: 0.2354 - val_accuracy: 0.9333
# Epoch 45/200
# 22/22 [==============================] - 0s 1ms/step - loss: 0.2985 - accuracy: 0.9057 - val_loss: 0.2286 - val_accuracy: 0.9333
# Epoch 46/200
# 22/22 [==============================] - 0s 1ms/step - loss: 0.3257 - accuracy: 0.8814 - val_loss: 0.2203 - val_accuracy: 0.9333
# Epoch 47/200
# 22/22 [==============================] - 0s 1ms/step - loss: 0.3098 - accuracy: 0.8914 - val_loss: 0.2145 - val_accuracy: 0.9333
# Epoch 48/200
# 22/22 [==============================] - 0s 1ms/step - loss: 0.2862 - accuracy: 0.9000 - val_loss: 0.2039 - val_accuracy: 0.9500
# Epoch 49/200
# 22/22 [==============================] - 0s 1ms/step - loss: 0.2895 - accuracy: 0.8971 - val_loss: 0.1982 - val_accuracy: 0.9500
# Epoch 50/200
# 22/22 [==============================] - 0s 1ms/step - loss: 0.2857 - accuracy: 0.8943 - val_loss: 0.1884 - val_accuracy: 0.9500
# Epoch 51/200
# 22/22 [==============================] - 0s 1ms/step - loss: 0.2765 - accuracy: 0.9100 - val_loss: 0.1852 - val_accuracy: 0.9600
# Epoch 52/200
# 22/22 [==============================] - 0s 1ms/step - loss: 0.2598 - accuracy: 0.9114 - val_loss: 0.1768 - val_accuracy: 0.9600
# Epoch 53/200
# 22/22 [==============================] - 0s 1ms/step - loss: 0.2668 - accuracy: 0.9129 - val_loss: 0.1649 - val_accuracy: 0.9600
# Epoch 54/200
# 22/22 [==============================] - 0s 1ms/step - loss: 0.2462 - accuracy: 0.9114 - val_loss: 0.1585 - val_accuracy: 0.9600
# Epoch 55/200
# 22/22 [==============================] - 0s 2ms/step - loss: 0.2487 - accuracy: 0.9171 - val_loss: 0.1536 - val_accuracy: 0.9600
# Epoch 56/200
# 22/22 [==============================] - 0s 1ms/step - loss: 0.2272 - accuracy: 0.9286 - val_loss: 0.1565 - val_accuracy: 0.9600
# Epoch 57/200
# 22/22 [==============================] - 0s 1ms/step - loss: 0.2240 - accuracy: 0.9271 - val_loss: 0.1463 - val_accuracy: 0.9600
# Epoch 58/200
# 22/22 [==============================] - 0s 1ms/step - loss: 0.2140 - accuracy: 0.9286 - val_loss: 0.1421 - val_accuracy: 0.9600
# Epoch 59/200
# 22/22 [==============================] - 0s 2ms/step - loss: 0.2237 - accuracy: 0.9243 - val_loss: 0.1377 - val_accuracy: 0.9600
# Epoch 60/200
# 22/22 [==============================] - 0s 1ms/step - loss: 0.2081 - accuracy: 0.9329 - val_loss: 0.1315 - val_accuracy: 0.9500
# Epoch 61/200
# 22/22 [==============================] - 0s 2ms/step - loss: 0.2088 - accuracy: 0.9229 - val_loss: 0.1291 - val_accuracy: 0.9600
# Epoch 62/200
# 22/22 [==============================] - 0s 1ms/step - loss: 0.1885 - accuracy: 0.9329 - val_loss: 0.1197 - val_accuracy: 0.9600
# Epoch 63/200
# 22/22 [==============================] - 0s 1ms/step - loss: 0.1904 - accuracy: 0.9343 - val_loss: 0.1144 - val_accuracy: 0.9667
# Epoch 64/200
# 22/22 [==============================] - 0s 1ms/step - loss: 0.1856 - accuracy: 0.9414 - val_loss: 0.1146 - val_accuracy: 0.9667
# Epoch 65/200
# 22/22 [==============================] - 0s 1ms/step - loss: 0.1780 - accuracy: 0.9386 - val_loss: 0.1195 - val_accuracy: 0.9600
# Epoch 66/200
# 22/22 [==============================] - 0s 1ms/step - loss: 0.1697 - accuracy: 0.9429 - val_loss: 0.1088 - val_accuracy: 0.9667
# Epoch 67/200
# 22/22 [==============================] - 0s 1ms/step - loss: 0.1653 - accuracy: 0.9500 - val_loss: 0.1040 - val_accuracy: 0.9667
# Epoch 68/200
# 22/22 [==============================] - 0s 1ms/step - loss: 0.1575 - accuracy: 0.9500 - val_loss: 0.1018 - val_accuracy: 0.9667
# Epoch 69/200
# 22/22 [==============================] - 0s 1ms/step - loss: 0.1582 - accuracy: 0.9443 - val_loss: 0.1001 - val_accuracy: 0.9667
# Epoch 70/200
# 22/22 [==============================] - 0s 1ms/step - loss: 0.1557 - accuracy: 0.9414 - val_loss: 0.0940 - val_accuracy: 0.9667
# Epoch 71/200
# 22/22 [==============================] - 0s 1ms/step - loss: 0.1500 - accuracy: 0.9486 - val_loss: 0.0964 - val_accuracy: 0.9733
# Epoch 72/200
# 22/22 [==============================] - 0s 1ms/step - loss: 0.1523 - accuracy: 0.9471 - val_loss: 0.0923 - val_accuracy: 0.9733
# Epoch 73/200
# 22/22 [==============================] - 0s 1ms/step - loss: 0.1348 - accuracy: 0.9586 - val_loss: 0.0809 - val_accuracy: 0.9833
# Epoch 74/200
# 22/22 [==============================] - 0s 1ms/step - loss: 0.1226 - accuracy: 0.9700 - val_loss: 0.0806 - val_accuracy: 0.9767
# Epoch 75/200
# 22/22 [==============================] - 0s 1ms/step - loss: 0.1209 - accuracy: 0.9700 - val_loss: 0.0724 - val_accuracy: 0.9833
# Epoch 76/200
# 22/22 [==============================] - 0s 1ms/step - loss: 0.1267 - accuracy: 0.9643 - val_loss: 0.0735 - val_accuracy: 0.9833
# Epoch 77/200
# 22/22 [==============================] - 0s 1ms/step - loss: 0.1192 - accuracy: 0.9643 - val_loss: 0.0822 - val_accuracy: 0.9667
# Epoch 78/200
# 22/22 [==============================] - 0s 1ms/step - loss: 0.1219 - accuracy: 0.9671 - val_loss: 0.0741 - val_accuracy: 0.9833
# Epoch 79/200
# 22/22 [==============================] - 0s 1ms/step - loss: 0.1217 - accuracy: 0.9671 - val_loss: 0.0659 - val_accuracy: 0.9833
# Epoch 80/200
# 22/22 [==============================] - 0s 1ms/step - loss: 0.1184 - accuracy: 0.9586 - val_loss: 0.0663 - val_accuracy: 0.9833
# Epoch 81/200
# 22/22 [==============================] - 0s 1ms/step - loss: 0.1102 - accuracy: 0.9700 - val_loss: 0.0619 - val_accuracy: 0.9833
# Epoch 82/200
# 22/22 [==============================] - 0s 1ms/step - loss: 0.0996 - accuracy: 0.9729 - val_loss: 0.0605 - val_accuracy: 0.9833
# Epoch 83/200
# 22/22 [==============================] - 0s 1ms/step - loss: 0.1060 - accuracy: 0.9686 - val_loss: 0.0604 - val_accuracy: 0.9833
# Epoch 84/200
# 22/22 [==============================] - 0s 1ms/step - loss: 0.1014 - accuracy: 0.9671 - val_loss: 0.0594 - val_accuracy: 0.9833
# Epoch 85/200
# 22/22 [==============================] - 0s 1ms/step - loss: 0.1062 - accuracy: 0.9686 - val_loss: 0.0568 - val_accuracy: 0.9833
# Epoch 86/200
# 22/22 [==============================] - 0s 1ms/step - loss: 0.0918 - accuracy: 0.9714 - val_loss: 0.0553 - val_accuracy: 0.9833
# Epoch 87/200
# 22/22 [==============================] - 0s 1ms/step - loss: 0.0934 - accuracy: 0.9714 - val_loss: 0.0562 - val_accuracy: 0.9833
# Epoch 88/200
# 22/22 [==============================] - 0s 1ms/step - loss: 0.0838 - accuracy: 0.9714 - val_loss: 0.0531 - val_accuracy: 0.9833
# Epoch 89/200
# 22/22 [==============================] - 0s 1ms/step - loss: 0.1050 - accuracy: 0.9614 - val_loss: 0.0561 - val_accuracy: 0.9833
# Epoch 90/200
# 22/22 [==============================] - 0s 1ms/step - loss: 0.1003 - accuracy: 0.9671 - val_loss: 0.0526 - val_accuracy: 0.9833
# Epoch 91/200
# 22/22 [==============================] - 0s 1ms/step - loss: 0.0921 - accuracy: 0.9700 - val_loss: 0.0511 - val_accuracy: 0.9833
# Epoch 92/200
# 22/22 [==============================] - 0s 2ms/step - loss: 0.0802 - accuracy: 0.9729 - val_loss: 0.0496 - val_accuracy: 0.9833
# Epoch 93/200
# 22/22 [==============================] - 0s 1ms/step - loss: 0.0890 - accuracy: 0.9729 - val_loss: 0.0491 - val_accuracy: 0.9833
# Epoch 94/200
# 22/22 [==============================] - 0s 1ms/step - loss: 0.0789 - accuracy: 0.9729 - val_loss: 0.0478 - val_accuracy: 0.9833
# Epoch 95/200
# 22/22 [==============================] - 0s 1ms/step - loss: 0.0820 - accuracy: 0.9729 - val_loss: 0.0470 - val_accuracy: 0.9833
# Epoch 96/200
# 22/22 [==============================] - 0s 1ms/step - loss: 0.0907 - accuracy: 0.9671 - val_loss: 0.0470 - val_accuracy: 0.9833
# Epoch 97/200
# 22/22 [==============================] - 0s 1ms/step - loss: 0.0742 - accuracy: 0.9786 - val_loss: 0.0453 - val_accuracy: 0.9833
# Epoch 98/200
# 22/22 [==============================] - 0s 1ms/step - loss: 0.0821 - accuracy: 0.9700 - val_loss: 0.0440 - val_accuracy: 0.9833
# Epoch 99/200
# 22/22 [==============================] - 0s 1ms/step - loss: 0.0796 - accuracy: 0.9743 - val_loss: 0.0439 - val_accuracy: 0.9833
# Epoch 100/200
# 22/22 [==============================] - 0s 1ms/step - loss: 0.0728 - accuracy: 0.9729 - val_loss: 0.0433 - val_accuracy: 0.9833
# Epoch 101/200
# 22/22 [==============================] - 0s 1ms/step - loss: 0.0790 - accuracy: 0.9714 - val_loss: 0.0421 - val_accuracy: 0.9833
# Epoch 102/200
# 22/22 [==============================] - 0s 1ms/step - loss: 0.0695 - accuracy: 0.9786 - val_loss: 0.0419 - val_accuracy: 0.9833
# Epoch 103/200
# 22/22 [==============================] - 0s 1ms/step - loss: 0.0744 - accuracy: 0.9743 - val_loss: 0.0409 - val_accuracy: 0.9833
# Epoch 104/200
# 22/22 [==============================] - 0s 1ms/step - loss: 0.0704 - accuracy: 0.9729 - val_loss: 0.0360 - val_accuracy: 0.9833
# Epoch 105/200
# 22/22 [==============================] - 0s 1ms/step - loss: 0.0670 - accuracy: 0.9714 - val_loss: 0.0342 - val_accuracy: 0.9833
# Epoch 106/200
# 22/22 [==============================] - 0s 1ms/step - loss: 0.0677 - accuracy: 0.9714 - val_loss: 0.0318 - val_accuracy: 0.9833
# Epoch 107/200
# 22/22 [==============================] - 0s 1ms/step - loss: 0.0620 - accuracy: 0.9786 - val_loss: 0.0317 - val_accuracy: 0.9833
# Epoch 108/200
# 22/22 [==============================] - 0s 1ms/step - loss: 0.0593 - accuracy: 0.9771 - val_loss: 0.0299 - val_accuracy: 0.9833
# Epoch 109/200
# 22/22 [==============================] - 0s 1ms/step - loss: 0.0573 - accuracy: 0.9743 - val_loss: 0.0277 - val_accuracy: 0.9833
# Epoch 110/200
# 22/22 [==============================] - 0s 1ms/step - loss: 0.0644 - accuracy: 0.9671 - val_loss: 0.0335 - val_accuracy: 0.9833
# Epoch 111/200
# 22/22 [==============================] - 0s 1ms/step - loss: 0.0436 - accuracy: 0.9871 - val_loss: 0.0242 - val_accuracy: 1.0000
# Epoch 112/200
# 22/22 [==============================] - 0s 1ms/step - loss: 0.0536 - accuracy: 0.9814 - val_loss: 0.0158 - val_accuracy: 1.0000
# Epoch 113/200
# 22/22 [==============================] - 0s 1ms/step - loss: 0.0379 - accuracy: 0.9886 - val_loss: 0.0146 - val_accuracy: 1.0000
# Epoch 114/200
# 22/22 [==============================] - 0s 1ms/step - loss: 0.0275 - accuracy: 0.9986 - val_loss: 0.0121 - val_accuracy: 1.0000
# Epoch 115/200
# 22/22 [==============================] - 0s 1ms/step - loss: 0.0316 - accuracy: 0.9957 - val_loss: 0.0094 - val_accuracy: 1.0000
# Epoch 116/200
# 22/22 [==============================] - 0s 1ms/step - loss: 0.0236 - accuracy: 0.9986 - val_loss: 0.0084 - val_accuracy: 1.0000
# Epoch 117/200
# 22/22 [==============================] - 0s 1ms/step - loss: 0.0277 - accuracy: 0.9971 - val_loss: 0.0092 - val_accuracy: 1.0000
# Epoch 118/200
# 22/22 [==============================] - 0s 1ms/step - loss: 0.0301 - accuracy: 0.9971 - val_loss: 0.0072 - val_accuracy: 1.0000
# Epoch 119/200
# 22/22 [==============================] - 0s 1ms/step - loss: 0.0213 - accuracy: 0.9957 - val_loss: 0.0068 - val_accuracy: 1.0000
# Epoch 120/200
# 22/22 [==============================] - 0s 1ms/step - loss: 0.0224 - accuracy: 0.9957 - val_loss: 0.0067 - val_accuracy: 1.0000
# Epoch 121/200
# 22/22 [==============================] - 0s 1ms/step - loss: 0.0293 - accuracy: 0.9943 - val_loss: 0.0066 - val_accuracy: 1.0000
# Epoch 122/200
# 22/22 [==============================] - 0s 1ms/step - loss: 0.0181 - accuracy: 0.9986 - val_loss: 0.0062 - val_accuracy: 1.0000
# Epoch 123/200
# 22/22 [==============================] - 0s 1ms/step - loss: 0.0206 - accuracy: 0.9943 - val_loss: 0.0050 - val_accuracy: 1.0000
# Epoch 124/200
# 22/22 [==============================] - 0s 1ms/step - loss: 0.0283 - accuracy: 0.9900 - val_loss: 0.0061 - val_accuracy: 1.0000
# Epoch 125/200
# 22/22 [==============================] - 0s 1ms/step - loss: 0.0185 - accuracy: 0.9957 - val_loss: 0.0045 - val_accuracy: 1.0000
# Epoch 126/200
# 22/22 [==============================] - 0s 1ms/step - loss: 0.0194 - accuracy: 0.9971 - val_loss: 0.0055 - val_accuracy: 1.0000
# Epoch 127/200
# 22/22 [==============================] - 0s 2ms/step - loss: 0.0175 - accuracy: 0.9986 - val_loss: 0.0047 - val_accuracy: 1.0000
# Epoch 128/200
# 22/22 [==============================] - 0s 1ms/step - loss: 0.0150 - accuracy: 1.0000 - val_loss: 0.0036 - val_accuracy: 1.0000
# Epoch 129/200
# 22/22 [==============================] - 0s 1ms/step - loss: 0.0124 - accuracy: 0.9986 - val_loss: 0.0032 - val_accuracy: 1.0000
# Epoch 130/200
# 22/22 [==============================] - 0s 1ms/step - loss: 0.0119 - accuracy: 1.0000 - val_loss: 0.0031 - val_accuracy: 1.0000
# Epoch 131/200
# 22/22 [==============================] - 0s 1ms/step - loss: 0.0161 - accuracy: 0.9957 - val_loss: 0.0032 - val_accuracy: 1.0000
# Epoch 132/200
# 22/22 [==============================] - 0s 1ms/step - loss: 0.0166 - accuracy: 0.9957 - val_loss: 0.0038 - val_accuracy: 1.0000
# Epoch 133/200
# 22/22 [==============================] - 0s 1ms/step - loss: 0.0109 - accuracy: 0.9986 - val_loss: 0.0028 - val_accuracy: 1.0000
# Epoch 134/200
# 22/22 [==============================] - 0s 1ms/step - loss: 0.0098 - accuracy: 0.9986 - val_loss: 0.0026 - val_accuracy: 1.0000
# Epoch 135/200
# 22/22 [==============================] - 0s 1ms/step - loss: 0.0136 - accuracy: 0.9971 - val_loss: 0.0021 - val_accuracy: 1.0000
# Epoch 136/200
# 22/22 [==============================] - 0s 1ms/step - loss: 0.0162 - accuracy: 0.9957 - val_loss: 0.0021 - val_accuracy: 1.0000
# Epoch 137/200
# 22/22 [==============================] - 0s 1ms/step - loss: 0.0111 - accuracy: 0.9971 - val_loss: 0.0023 - val_accuracy: 1.0000
# Epoch 138/200
# 22/22 [==============================] - 0s 1ms/step - loss: 0.0160 - accuracy: 0.9957 - val_loss: 0.0027 - val_accuracy: 1.0000
# Epoch 139/200
# 22/22 [==============================] - 0s 1ms/step - loss: 0.0198 - accuracy: 0.9971 - val_loss: 0.0024 - val_accuracy: 1.0000
# Epoch 140/200
# 22/22 [==============================] - 0s 2ms/step - loss: 0.0108 - accuracy: 0.9986 - val_loss: 0.0020 - val_accuracy: 1.0000
# Epoch 141/200
# 22/22 [==============================] - 0s 1ms/step - loss: 0.0149 - accuracy: 0.9971 - val_loss: 0.0020 - val_accuracy: 1.0000
# Epoch 142/200
# 22/22 [==============================] - 0s 1ms/step - loss: 0.0127 - accuracy: 0.9957 - val_loss: 0.0024 - val_accuracy: 1.0000
# Epoch 143/200
# 22/22 [==============================] - 0s 1ms/step - loss: 0.0161 - accuracy: 0.9971 - val_loss: 0.0023 - val_accuracy: 1.0000
# Epoch 144/200
# 22/22 [==============================] - 0s 1ms/step - loss: 0.0131 - accuracy: 0.9957 - val_loss: 0.0027 - val_accuracy: 1.0000
# Epoch 145/200
# 22/22 [==============================] - 0s 1ms/step - loss: 0.0105 - accuracy: 0.9986 - val_loss: 0.0024 - val_accuracy: 1.0000
# Epoch 146/200
# 22/22 [==============================] - 0s 1ms/step - loss: 0.0074 - accuracy: 1.0000 - val_loss: 0.0018 - val_accuracy: 1.0000
# Epoch 147/200
# 22/22 [==============================] - 0s 1ms/step - loss: 0.0143 - accuracy: 0.9986 - val_loss: 0.0017 - val_accuracy: 1.0000
# Epoch 148/200
# 22/22 [==============================] - 0s 1ms/step - loss: 0.0103 - accuracy: 0.9986 - val_loss: 0.0019 - val_accuracy: 1.0000
# Epoch 149/200
# 22/22 [==============================] - 0s 1ms/step - loss: 0.0078 - accuracy: 1.0000 - val_loss: 0.0019 - val_accuracy: 1.0000
# Epoch 150/200
# 22/22 [==============================] - 0s 1ms/step - loss: 0.0065 - accuracy: 1.0000 - val_loss: 0.0019 - val_accuracy: 1.0000
# Epoch 151/200
# 22/22 [==============================] - 0s 1ms/step - loss: 0.0059 - accuracy: 1.0000 - val_loss: 0.0016 - val_accuracy: 1.0000
# Epoch 152/200
# 22/22 [==============================] - 0s 1ms/step - loss: 0.0103 - accuracy: 0.9971 - val_loss: 0.0018 - val_accuracy: 1.0000
# Epoch 153/200
# 22/22 [==============================] - 0s 1ms/step - loss: 0.0051 - accuracy: 1.0000 - val_loss: 0.0017 - val_accuracy: 1.0000
# Epoch 154/200
# 22/22 [==============================] - 0s 1ms/step - loss: 0.0084 - accuracy: 0.9986 - val_loss: 0.0012 - val_accuracy: 1.0000
# Epoch 155/200
# 22/22 [==============================] - 0s 1ms/step - loss: 0.0144 - accuracy: 0.9971 - val_loss: 0.0017 - val_accuracy: 1.0000
# Epoch 156/200
# 22/22 [==============================] - 0s 1ms/step - loss: 0.0093 - accuracy: 0.9986 - val_loss: 0.0019 - val_accuracy: 1.0000
# Epoch 157/200
# 22/22 [==============================] - 0s 1ms/step - loss: 0.0126 - accuracy: 0.9971 - val_loss: 0.0016 - val_accuracy: 1.0000
# Epoch 158/200
# 22/22 [==============================] - 0s 1ms/step - loss: 0.0070 - accuracy: 1.0000 - val_loss: 0.0013 - val_accuracy: 1.0000
# Epoch 159/200
# 22/22 [==============================] - 0s 1ms/step - loss: 0.0069 - accuracy: 0.9986 - val_loss: 0.0012 - val_accuracy: 1.0000
# Epoch 160/200
# 22/22 [==============================] - 0s 1ms/step - loss: 0.0056 - accuracy: 1.0000 - val_loss: 0.0012 - val_accuracy: 1.0000
# Epoch 161/200
# 22/22 [==============================] - 0s 1ms/step - loss: 0.0052 - accuracy: 1.0000 - val_loss: 0.0012 - val_accuracy: 1.0000
# Epoch 162/200
# 22/22 [==============================] - 0s 1ms/step - loss: 0.0051 - accuracy: 1.0000 - val_loss: 0.0011 - val_accuracy: 1.0000
# Epoch 163/200
# 22/22 [==============================] - 0s 1ms/step - loss: 0.0057 - accuracy: 0.9986 - val_loss: 0.0013 - val_accuracy: 1.0000
# Epoch 164/200
# 22/22 [==============================] - 0s 1ms/step - loss: 0.0045 - accuracy: 1.0000 - val_loss: 0.0011 - val_accuracy: 1.0000
# Epoch 165/200
# 22/22 [==============================] - ETA: 0s - loss: 0.0093 - accuracy: 1.00 - 0s 1ms/step - loss: 0.0075 - accuracy: 0.9986 - val_loss: 0.0011 - val_accuracy: 1.0000
# Epoch 166/200
# 22/22 [==============================] - 0s 1ms/step - loss: 0.0038 - accuracy: 1.0000 - val_loss: 0.0010 - val_accuracy: 1.0000
# Epoch 167/200
# 22/22 [==============================] - 0s 1ms/step - loss: 0.0051 - accuracy: 0.9986 - val_loss: 7.7207e-04 - val_accuracy: 1.0000
# Epoch 168/200
# 22/22 [==============================] - 0s 1ms/step - loss: 0.0052 - accuracy: 1.0000 - val_loss: 8.1929e-04 - val_accuracy: 1.0000
# Epoch 169/200
# 22/22 [==============================] - 0s 1ms/step - loss: 0.0049 - accuracy: 0.9986 - val_loss: 0.0011 - val_accuracy: 1.0000
# Epoch 170/200
# 22/22 [==============================] - 0s 1ms/step - loss: 0.0047 - accuracy: 0.9986 - val_loss: 9.0622e-04 - val_accuracy: 1.0000
# Epoch 171/200
# 22/22 [==============================] - 0s 1ms/step - loss: 0.0042 - accuracy: 1.0000 - val_loss: 7.3150e-04 - val_accuracy: 1.0000
# Epoch 172/200
# 22/22 [==============================] - 0s 1ms/step - loss: 0.0111 - accuracy: 0.9957 - val_loss: 8.3985e-04 - val_accuracy: 1.0000
# Epoch 173/200
# 22/22 [==============================] - 0s 1ms/step - loss: 0.0162 - accuracy: 0.9986 - val_loss: 8.3273e-04 - val_accuracy: 1.0000
# Epoch 174/200
# 22/22 [==============================] - 0s 1ms/step - loss: 0.0100 - accuracy: 0.9971 - val_loss: 0.0018 - val_accuracy: 1.0000
# Epoch 175/200
# 22/22 [==============================] - 0s 1ms/step - loss: 0.0060 - accuracy: 1.0000 - val_loss: 0.0018 - val_accuracy: 1.0000
# Epoch 176/200
# 22/22 [==============================] - 0s 1ms/step - loss: 0.0054 - accuracy: 1.0000 - val_loss: 7.0320e-04 - val_accuracy: 1.0000
# Epoch 177/200
# 22/22 [==============================] - 0s 2ms/step - loss: 0.0062 - accuracy: 0.9986 - val_loss: 9.0275e-04 - val_accuracy: 1.0000
# Epoch 178/200
# 22/22 [==============================] - 0s 1ms/step - loss: 0.0049 - accuracy: 0.9986 - val_loss: 7.9813e-04 - val_accuracy: 1.0000
# Epoch 179/200
# 22/22 [==============================] - 0s 1ms/step - loss: 0.0059 - accuracy: 0.9986 - val_loss: 8.7681e-04 - val_accuracy: 1.0000
# Epoch 180/200
# 22/22 [==============================] - 0s 1ms/step - loss: 0.0092 - accuracy: 0.9971 - val_loss: 8.2480e-04 - val_accuracy: 1.0000
# Epoch 181/200
# 22/22 [==============================] - 0s 1ms/step - loss: 0.0128 - accuracy: 0.9971 - val_loss: 7.7367e-04 - val_accuracy: 1.0000
# Epoch 182/200
# 22/22 [==============================] - 0s 1ms/step - loss: 0.0083 - accuracy: 0.9986 - val_loss: 0.0020 - val_accuracy: 1.0000
# Epoch 183/200
# 22/22 [==============================] - 0s 1ms/step - loss: 0.0034 - accuracy: 1.0000 - val_loss: 7.4529e-04 - val_accuracy: 1.0000
# Epoch 184/200
# 22/22 [==============================] - 0s 1ms/step - loss: 0.0064 - accuracy: 0.9986 - val_loss: 0.0010 - val_accuracy: 1.0000
# Epoch 185/200
# 22/22 [==============================] - 0s 1ms/step - loss: 0.0045 - accuracy: 1.0000 - val_loss: 5.2832e-04 - val_accuracy: 1.0000
# Epoch 186/200
# 22/22 [==============================] - 0s 1ms/step - loss: 0.0021 - accuracy: 1.0000 - val_loss: 4.1429e-04 - val_accuracy: 1.0000
# Epoch 187/200
# 22/22 [==============================] - 0s 1ms/step - loss: 0.0102 - accuracy: 0.9971 - val_loss: 8.3282e-04 - val_accuracy: 1.0000
# Epoch 188/200
# 22/22 [==============================] - 0s 1ms/step - loss: 0.0081 - accuracy: 0.9971 - val_loss: 0.0018 - val_accuracy: 1.0000
# Epoch 189/200
# 22/22 [==============================] - 0s 1ms/step - loss: 0.0056 - accuracy: 0.9986 - val_loss: 9.1714e-04 - val_accuracy: 1.0000
# Epoch 190/200
# 22/22 [==============================] - 0s 1ms/step - loss: 0.0058 - accuracy: 0.9986 - val_loss: 5.1662e-04 - val_accuracy: 1.0000
# Epoch 191/200
# 22/22 [==============================] - 0s 1ms/step - loss: 0.0048 - accuracy: 0.9986 - val_loss: 6.1081e-04 - val_accuracy: 1.0000
# Epoch 192/200
# 22/22 [==============================] - 0s 1ms/step - loss: 0.0039 - accuracy: 1.0000 - val_loss: 4.6977e-04 - val_accuracy: 1.0000
# Epoch 193/200
# 22/22 [==============================] - 0s 1ms/step - loss: 0.0037 - accuracy: 0.9986 - val_loss: 3.0503e-04 - val_accuracy: 1.0000
# Epoch 194/200
# 22/22 [==============================] - 0s 1ms/step - loss: 0.0023 - accuracy: 1.0000 - val_loss: 2.8109e-04 - val_accuracy: 1.0000
# Epoch 195/200
# 22/22 [==============================] - 0s 1ms/step - loss: 0.0036 - accuracy: 0.9986 - val_loss: 3.3622e-04 - val_accuracy: 1.0000
# Epoch 196/200
# 22/22 [==============================] - 0s 1ms/step - loss: 0.0037 - accuracy: 1.0000 - val_loss: 5.1978e-04 - val_accuracy: 1.0000
# Epoch 197/200
# 22/22 [==============================] - 0s 1ms/step - loss: 0.0031 - accuracy: 1.0000 - val_loss: 3.4452e-04 - val_accuracy: 1.0000
# Epoch 198/200
# 22/22 [==============================] - 0s 1ms/step - loss: 0.0068 - accuracy: 0.9971 - val_loss: 0.0036 - val_accuracy: 0.9967
# Epoch 199/200
# 22/22 [==============================] - 0s 1ms/step - loss: 0.0044 - accuracy: 1.0000 - val_loss: 2.5297e-04 - val_accuracy: 1.0000
# Epoch 200/200
# 22/22 [==============================] - 0s 1ms/step - loss: 0.0183 - accuracy: 0.9943 - val_loss: 4.4531e-04 - val_accuracy: 1.0000

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 8)                 192
# _________________________________________________________________
# dense_1 (Dense)              (None, 16)                144
# _________________________________________________________________
# dropout (Dropout)            (None, 16)                0
# _________________________________________________________________
# dense_2 (Dense)              (None, 8)                 136
# _________________________________________________________________
# dense_3 (Dense)              (None, 3)                 27
# =================================================================
# Total params: 499
# Trainable params: 499
# Non-trainable params: 0
# _________________________________________________________________

# %%
# drawing a plot to see the accuracy of the data
plt.figure(figsize = (12,8))
plt.xlabel("Number of Epochs")
plt.ylabel("Accuracy of Data")
plt.plot(dlModel.history["accuracy"], label = "Training accuracy", marker = "o", color = "darkblue",)
plt.plot(dlModel.history["val_accuracy"],label = "Validation accuracy", marker = "o",color = "r",)
plt.title("Training VS Validation Accuracy", fontsize = 18)
plt.legend()
plt.show()

# %%
# drawing a plot to see loss data
plt.figure(figsize = (12,8))
plt.xlabel("Number of Epochs")
plt.ylabel("Loss in Data")
plt.plot(dlModel.history["loss"], label= "Training loss", marker = "o", color = "darkblue",)
plt.plot(dlModel.history["val_loss"], label= "Validation loss", marker = "o", color = "r",)
plt.title("Training VS Validation loss", fontsize = 18)
plt.legend()
plt.show()

# %% [markdown]
# ### Thank You and See You in Other Datasets
